# %% [markdown]
# # My Jupuyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Tarek, Business owner

# %% [markdown]
# _I am interested in data science because I love the idea of being able to gain insights by going through large amounts of data._

# %% [markdown]
# ### My code needs to substract 3 from 5

# %%
5-3
# Out:
# 2

# %% [markdown]
# - one
# - two
# - three
#
# [click here to see the where I found the IBM logo !](https://fr.m.wikipedia.org/wiki/Fichier:IBM_logo.svg)
#
# ![IBM_logo.svg (1).png](attachment:786f8a3f-e11d-44a7-863a-02b072ab1633.png)
